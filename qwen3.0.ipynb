# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_path = r"D:\lianxi\Qwen\qwen\Qwen\Qwen3-0.6B"
device = "cuda" if torch.cuda.is_available() else "cpu"

# 加载模型
model = AutoModelForCausalLM.from_pretrained(
    model_path,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
)

# 加载 tokenizer
tokenizer = AutoTokenizer.from_pretrained(
    model_path,
    trust_remote_code=True
)

# 测试推理
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "用一句话介绍通义千问Qwen3大模型"}
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)
model_inputs = tokenizer([text], return_tensors="pt").to(device)

generated_ids = model.generate(
    model_inputs.input_ids,
    max_new_tokens=512
)
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
print("模型回复：\n", response)
# Out:
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 1513.92it/s]
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Qwen3ForCausalLM LOAD REPORT from: D:\lianxi\Qwen\qwen\Qwen\Qwen3-0.6B
# Key                                                   | Status  |
# ------------------------------------------------------+---------+-
# model.layers.{28, 29}.mlp.up_proj.weight              | MISSING |
# model.layers.{28, 29}.mlp.down_proj.weight            | MISSING |
# model.layers.{28, 29}.post_attention_layernorm.weight | MISSING |
# model.layers.{28, 29}.self_attn.q_norm.weight         | MISSING |
# model.layers.{28, 29}.input_layernorm.weight          | MISSING |
# model.layers.{28, 29}.self_attn.o_proj.weight         | MISSING |
# model.layers.{28, 29}.self_attn.k_proj.weight         | MISSING |
# model.layers.{28, 29}.self_attn.v_proj.weight         | MISSING |
# model.layers.{28, 29}.self_attn.k_norm.weight         | MISSING |
# model.layers.{28, 29}.self_attn.q_proj.weight         | MISSING |
# model.layers.{28, 29}.mlp.gate_proj.weight            | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# 模型回复：
#  <think>
# 好的，用户让我用一句话介绍通义千问Qwen3大模型。首先，我需要确认用户的需求是什么。他们可能是在准备项目，或者需要快速了解这个模型的特点，所以需要简洁明了的介绍。
#
# 接下来，我需要回忆通义千问Qwen3的主要特点。大模型通常具备强大的语言理解和生成能力，支持多语言，还有多种应用场景。用户可能需要强调这些优势，比如多模态处理、高效计算等。
#
# 然后，我要考虑用户可能的深层需求。他们可能希望这句话既准确又吸引人，适合用于宣传、报告或技术文档。所以，我需要确保信息全面但不过于冗长。
#
# 还要注意术语的正确使用，比如“通义千问”是品牌，而Qwen3是版本，要正确区分。另外，是否需要提到模型的性能指标，比如参数量、推理速度等，但用户只要一句话，所以可能不需要太详细。
#
# 最后，检查句子的流畅性和信息的完整性，确保没有遗漏关键点，同时保持简洁。确认没有使用复杂结构，让用户容易理解。
# </think>
#
# 通义千问Qwen3大模型是一款集语言理解和生成能力于一体的多模态大模型，具备强大的跨语言理解和生成能力，适用于多种应用场景。
